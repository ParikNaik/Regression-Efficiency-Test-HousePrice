# %% [markdown]
# Import Statements

# %%
import pandas as pd #Initilize dataframe + manipulate data
import matplotlib.pyplot as plt #Heat map + confusion matrix
import seaborn as sns #General summary stats
from sklearn.linear_model import LinearRegression #Multiple Linear Regression
